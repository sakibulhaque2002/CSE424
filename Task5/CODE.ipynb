# %%
#start time 2:41
#end time 3:23

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
data = pd.read_csv('/content/drive/MyDrive/440/IMDB Dataset.csv')
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print(data.columns)
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
reviews = data['review']
data['sentiment'] = data['sentiment'].map({'negative': 0, 'positive': 1})
labels = data['sentiment']

# %%
data.head()
# Out:
#                                               review  sentiment
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1

# %%
print(data['sentiment'].value_counts())
# Out:
# 1    25000
# 0    25000
# Name: sentiment, dtype: int64

# %%
# Load GloVe embeddings
def load_glove_embeddings(path):
    embeddings_index = {}
    with open(path) as f:
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs
    return embeddings_index

glove_path = '/content/drive/MyDrive/440/glove.6B.100d.txt'
glove_embeddings = load_glove_embeddings(glove_path)

# %%
# Tokenize and pad sequences

tokenizer = Tokenizer(num_words = 5000)
tokenizer.fit_on_texts(reviews)

sequences = tokenizer.texts_to_sequences(reviews)
word_index = tokenizer.word_index
data_padded = pad_sequences(sequences, maxlen=256)

print(reviews[2])
print(sequences[2])
print(len(data_padded[0]))
# Out:
# I thought this was a wonderful way to spend time on a too hot summer weekend, sitting in the air conditioned theater and watching a light-hearted comedy. The plot is simplistic, but the dialogue is witty and the characters are likable (even the well bread suspected serial killer). While some may be disappointed when they realize this is not Match Point 2: Risk Addiction, I thought it was proof that Woody Allen is still fully in control of the style many of us have grown to love.<br /><br />This was the most I'd laughed at one of Woody's comedies in years (dare I say a decade?). While I've never been impressed with Scarlet Johanson, in this she managed to tone down her "sexy" image and jumped right into a average, but spirited young woman.<br /><br />This may not be the crown jewel of his career, but it was wittier than "Devil Wears Prada" and more interesting than "Superman" a great comedy to go see with friends.
# [10, 190, 11, 13, 3, 393, 95, 5, 1155, 55, 20, 3, 96, 879, 1494, 2657, 1241, 8, 1, 903, 769, 2, 147, 3, 649, 2333, 202, 1, 111, 6, 4086, 18, 1, 410, 6, 1915, 2, 1, 102, 23, 1485, 57, 1, 69, 1574, 494, 136, 47, 200, 26, 680, 50, 33, 959, 11, 6, 21, 1026, 220, 230, 2917, 10, 190, 9, 13, 3059, 12, 2971, 2050, 6, 130, 1403, 8, 1139, 4, 1, 396, 106, 4, 176, 25, 2079, 5, 112, 7, 7, 11, 13, 1, 88, 482, 1451, 30, 27, 4, 1317, 8, 153, 3024, 10, 131, 3, 2121, 136, 198, 110, 75, 1508, 16, 8, 11, 59, 1323, 5, 1260, 175, 40, 1257, 1428, 2, 203, 82, 3, 848, 18, 3611, 186, 257, 7, 7, 11, 200, 21, 26, 1, 4, 24, 628, 18, 9, 13, 71, 2244, 2930, 2, 51, 218, 71, 2658, 3, 78, 202, 5, 139, 63, 16, 350]
# 256

# %%
# Prepare GloVe embedding matrix
embedding_matrix = np.zeros((len(word_index) + 1, 100))
for word, i in word_index.items():
    embedding_vector = glove_embeddings.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
vocab_size = len(word_index) + 1
nonzero_elements = np.count_nonzero(np.count_nonzero(embedding_matrix, axis=1))
nonzero_elements / vocab_size
# Out:
# 0.6044119659082678

# %%
# Spliting the data
X_train, X_test, y_train, y_test = train_test_split(data_padded, labels, test_size=0.2, random_state=42)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (40000, 256) (10000, 256) (40000,) (10000,)

# %%
print(data_padded.shape)
# Out:
# (50000, 256)

# %%
#Using Basic ML model
model = LogisticRegression()

model.fit(X_train, y_train)
score = model.score(X_test, y_test)

print('Accuracy', score)
# Out:
# Accuracy 0.519

# %%
# Shallow model with dense layers

embedding_dim = 100
vocab_size = len(word_index) + 1

model2 = Sequential()
model2.add(Embedding(vocab_size,
                     embedding_dim,
                     weights=[embedding_matrix],
                     input_length=256,
                     trainable=True))

model2.add(Dense(10, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))

model2.compile(optimizer='adam',
               loss='binary_crossentropy',
               metrics=['accuracy'])
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 256, 100)          12425300
#
#  dense_4 (Dense)             (None, 256, 10)           1010
#
#  dense_5 (Dense)             (None, 256, 1)            11
#
# =================================================================
# Total params: 12426321 (47.40 MB)
# Trainable params: 12426321 (47.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %%
# Train the shallow model
history=model2.fit(X_train, y_train, epochs=20, batch_size=30, validation_data=(X_test, y_test))

# loss2, accuracy2 = model2.evaluate(X_test, y_test)
# print(f'Shallow Model Test Accuracy: {accuracy2}')

loss2,accuracy2 = model2.evaluate(X_train, y_train, verbose = False)
print("Training Accuracy: {:.4f}".format(accuracy2))
loss2,accuracy2 = model2.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy2))


plot_history(history)
# accuracy 52 at batch_size 32, trainable = false
# accuracy 53 at batch_size 25, trainable = True
# accuracy 54 at batch_size 30, trainable = False
# Out:
# Epoch 1/20
# 1334/1334 [==============================] - 49s 36ms/step - loss: 0.6877 - accuracy: 0.5281 - val_loss: 0.6849 - val_accuracy: 0.5361
# Epoch 2/20
# 1334/1334 [==============================] - 15s 11ms/step - loss: 0.6849 - accuracy: 0.5337 - val_loss: 0.6862 - val_accuracy: 0.5333
# Epoch 3/20
# 1334/1334 [==============================] - 13s 10ms/step - loss: 0.6843 - accuracy: 0.5361 - val_loss: 0.6845 - val_accuracy: 0.5382
# Epoch 4/20
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6843 - accuracy: 0.5362 - val_loss: 0.6846 - val_accuracy: 0.5373
# Epoch 5/20
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6842 - accuracy: 0.5363 - val_loss: 0.6842 - val_accuracy: 0.5402
# Epoch 6/20
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6841 - accuracy: 0.5370 - val_loss: 0.6841 - val_accuracy: 0.5400
# Epoch 7/20
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6841 - accuracy: 0.5372 - val_loss: 0.6842 - val_accuracy: 0.5403
# Epoch 8/20
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6840 - accuracy: 0.5376 - val_loss: 0.6841 - val_accuracy: 0.5404
# Epoch 9/20
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6840 - accuracy: 0.5376 - val_loss: 0.6842 - val_accuracy: 0.5405
# Epoch 10/20
# 1334/1334 [==============================] - 11s 9ms/step - loss: 0.6840 - accuracy: 0.5377 - val_loss: 0.6841 - val_accuracy: 0.5400
# Epoch 11/20
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6839 - accuracy: 0.5375 - val_loss: 0.6842 - val_accuracy: 0.5401
# Epoch 12/20
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6840 - accuracy: 0.5373 - val_loss: 0.6842 - val_accuracy: 0.5400
# Epoch 13/20
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6839 - accuracy: 0.5374 - val_loss: 0.6841 - val_accuracy: 0.5401
# Epoch 14/20
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6839 - accuracy: 0.5377 - val_loss: 0.6840 - val_accuracy: 0.5407
# Epoch 15/20
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6839 - accuracy: 0.5379 - val_loss: 0.6843 - val_accuracy: 0.5405
# Epoch 16/20
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6839 - accuracy: 0.5379 - val_loss: 0.6840 - val_accuracy: 0.5407
# Epoch 17/20
# 1334/1334 [==============================] - 11s 9ms/step - loss: 0.6838 - accuracy: 0.5379 - val_loss: 0.6842 - val_accuracy: 0.5405
# Epoch 18/20
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6838 - accuracy: 0.5380 - val_loss: 0.6841 - val_accuracy: 0.5408
# Epoch 19/20
# 1334/1334 [==============================] - 10s 8ms/step - loss: 0.6838 - accuracy: 0.5381 - val_loss: 0.6841 - val_accuracy: 0.5406
# Epoch 20/20
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6839 - accuracy: 0.5381 - val_loss: 0.6840 - val_accuracy: 0.5407
# Training Accuracy: 0.5384
# Testing Accuracy:  0.5407

# %%
# LSTM model
model = Sequential()
model.add(Embedding(len(word_index) + 1, 100, weights=[embedding_matrix], input_length=256, trainable=True))
model.add(LSTM(10))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Total params: 12429751 (47.42 MB)
# Trainable params: 4451 (17.39 KB)
# Non-trainable params: 12425300 (47.40 MB)

# Total params: 12429751 (47.42 MB)
# Trainable params: 12429751 (47.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 256, 100)          12425300
#
#  lstm_2 (LSTM)               (None, 10)                4440
#
#  dense_6 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 12429751 (47.42 MB)
# Trainable params: 12429751 (47.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the LSTM model
history2=model.fit(X_train, y_train, epochs=20, batch_size=25, validation_data=(X_test, y_test))

# loss, accuracy = model.evaluate(X_test, y_test)
# print(f'LSTM Model Test Accuracy: {accuracy}')

loss,accuracy = model.evaluate(X_train, y_train, verbose = False)
print("LSTM Model Train Accuracy: {:.4f}".format(accuracy))
loss,accuracy = model.evaluate(X_test, y_test, verbose=False)
print("LSTM Model Test Accuracy {:.4f}".format(accuracy))


plot_history(history2)

# accuracy 85 at batch_size 32, trainable = false
# accuracy 86 at batch_size 32, trainable = false
# accuracy 88 at batch_size 25, trainable = false
# Out:
# Epoch 1/20
# 1600/1600 [==============================] - 60s 36ms/step - loss: 0.4021 - accuracy: 0.8108 - val_loss: 0.2753 - val_accuracy: 0.8877
# Epoch 2/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.2409 - accuracy: 0.9036 - val_loss: 0.2555 - val_accuracy: 0.8962
# Epoch 3/20
# 1600/1600 [==============================] - 25s 16ms/step - loss: 0.2002 - accuracy: 0.9223 - val_loss: 0.2596 - val_accuracy: 0.8964
# Epoch 4/20
# 1600/1600 [==============================] - 24s 15ms/step - loss: 0.1655 - accuracy: 0.9377 - val_loss: 0.2552 - val_accuracy: 0.8991
# Epoch 5/20
# 1600/1600 [==============================] - 24s 15ms/step - loss: 0.1318 - accuracy: 0.9528 - val_loss: 0.2807 - val_accuracy: 0.8970
# Epoch 6/20
# 1600/1600 [==============================] - 24s 15ms/step - loss: 0.1043 - accuracy: 0.9640 - val_loss: 0.3064 - val_accuracy: 0.8914
# Epoch 7/20
# 1600/1600 [==============================] - 23s 14ms/step - loss: 0.0788 - accuracy: 0.9743 - val_loss: 0.3530 - val_accuracy: 0.8911
# Epoch 8/20
# 1600/1600 [==============================] - 24s 15ms/step - loss: 0.0601 - accuracy: 0.9807 - val_loss: 0.4104 - val_accuracy: 0.8910
# Epoch 9/20
# 1600/1600 [==============================] - 24s 15ms/step - loss: 0.0478 - accuracy: 0.9855 - val_loss: 0.4636 - val_accuracy: 0.8903
# Epoch 10/20
# 1600/1600 [==============================] - 26s 16ms/step - loss: 0.0375 - accuracy: 0.9897 - val_loss: 0.4607 - val_accuracy: 0.8858
# Epoch 11/20
# 1600/1600 [==============================] - 24s 15ms/step - loss: 0.0285 - accuracy: 0.9923 - val_loss: 0.5316 - val_accuracy: 0.8853
# Epoch 12/20
# 1600/1600 [==============================] - 23s 15ms/step - loss: 0.0260 - accuracy: 0.9926 - val_loss: 0.5256 - val_accuracy: 0.8867
# Epoch 13/20
# 1600/1600 [==============================] - 24s 15ms/step - loss: 0.0213 - accuracy: 0.9942 - val_loss: 0.5677 - val_accuracy: 0.8881
# Epoch 14/20
# 1600/1600 [==============================] - 24s 15ms/step - loss: 0.0154 - accuracy: 0.9961 - val_loss: 0.6100 - val_accuracy: 0.8838
# Epoch 15/20
# 1600/1600 [==============================] - 23s 14ms/step - loss: 0.0203 - accuracy: 0.9945 - val_loss: 0.6225 - val_accuracy: 0.8809
# Epoch 16/20
# 1600/1600 [==============================] - 24s 15ms/step - loss: 0.0115 - accuracy: 0.9972 - val_loss: 0.6883 - val_accuracy: 0.8836
# Epoch 17/20
# 1600/1600 [==============================] - 23s 15ms/step - loss: 0.0153 - accuracy: 0.9959 - val_loss: 0.6109 - val_accuracy: 0.8805
# Epoch 18/20
# 1600/1600 [==============================] - 24s 15ms/step - loss: 0.0128 - accuracy: 0.9969 - val_loss: 0.6809 - val_accuracy: 0.8807
# Epoch 19/20
# 1600/1600 [==============================] - 24s 15ms/step - loss: 0.0130 - accuracy: 0.9966 - val_loss: 0.6943 - val_accuracy: 0.8772
# Epoch 20/20
# 1600/1600 [==============================] - 23s 14ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 0.7112 - val_accuracy: 0.8812
# LSTM Model Train Accuracy: 0.9984
# LSTM Model Test Accuracy 0.8812

# %%
# Bidirectional LSTM model
model1 = Sequential()
model1.add(Embedding(len(word_index) + 1, 100, weights=[embedding_matrix], input_length=256, trainable=True))
model1.add(Bidirectional(LSTM(10)))
model1.add(Dense(1, activation='sigmoid'))
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model1.summary()

# Total params: 12434201 (47.43 MB)
# Trainable params: 8901 (34.77 KB)
# Non-trainable params: 12425300 (47.40 MB)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 256, 100)          12425300
#
#  bidirectional_1 (Bidirecti  (None, 20)                8880
#  onal)
#
#  dense_7 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 12434201 (47.43 MB)
# Trainable params: 12434201 (47.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the Bidirectional LSTM model
history3 = model1.fit(X_train, y_train,
                      epochs=20,
                      batch_size=25,
                      validation_data=(X_test, y_test))

# loss, accuracy = model.evaluate(X_test, y_test)
# print(f'Bidirectional LSTM Model Test Accuracy: {accuracy}')

loss,accuracy = model1.evaluate(X_train, y_train, verbose = False)
print("Bidirectional LSTM Model Train Accuracy: {:.4f}".format(accuracy))
loss,accuracy = model1.evaluate(X_test, y_test, verbose=False)
print("Bidirectional LSTM Model Test Accuracy {:.4f}".format(accuracy))
plot_history(history3)

# trainable=True
#Bidirectional LSTM Model Train Accuracy: 0.9181
# Bidirectional LSTM Model Test Accuracy 0.8878
# Out:
# Epoch 1/20
# 1600/1600 [==============================] - 74s 44ms/step - loss: 0.4211 - accuracy: 0.8025 - val_loss: 0.3117 - val_accuracy: 0.8730
# Epoch 2/20
# 1600/1600 [==============================] - 42s 26ms/step - loss: 0.2470 - accuracy: 0.9041 - val_loss: 0.2634 - val_accuracy: 0.8948
# Epoch 3/20
# 1600/1600 [==============================] - 40s 25ms/step - loss: 0.2038 - accuracy: 0.9222 - val_loss: 0.2632 - val_accuracy: 0.8931
# Epoch 4/20
# 1600/1600 [==============================] - 40s 25ms/step - loss: 0.1709 - accuracy: 0.9369 - val_loss: 0.2851 - val_accuracy: 0.8856
# Epoch 5/20
# 1600/1600 [==============================] - 37s 23ms/step - loss: 0.1396 - accuracy: 0.9503 - val_loss: 0.2896 - val_accuracy: 0.8919
# Epoch 6/20
# 1600/1600 [==============================] - 39s 24ms/step - loss: 0.1081 - accuracy: 0.9628 - val_loss: 0.3335 - val_accuracy: 0.8874
# Epoch 7/20
# 1600/1600 [==============================] - 39s 24ms/step - loss: 0.0839 - accuracy: 0.9738 - val_loss: 0.3672 - val_accuracy: 0.8840
# Epoch 8/20
# 1600/1600 [==============================] - 38s 24ms/step - loss: 0.0641 - accuracy: 0.9809 - val_loss: 0.4240 - val_accuracy: 0.8765
# Epoch 9/20
# 1600/1600 [==============================] - 38s 24ms/step - loss: 0.0501 - accuracy: 0.9856 - val_loss: 0.4826 - val_accuracy: 0.8853
# Epoch 10/20
# 1600/1600 [==============================] - 39s 24ms/step - loss: 0.0409 - accuracy: 0.9877 - val_loss: 0.4852 - val_accuracy: 0.8822
# Epoch 11/20
# 1600/1600 [==============================] - 37s 23ms/step - loss: 0.0294 - accuracy: 0.9918 - val_loss: 0.5069 - val_accuracy: 0.8812
# Epoch 12/20
# 1600/1600 [==============================] - 38s 23ms/step - loss: 0.0257 - accuracy: 0.9928 - val_loss: 0.5562 - val_accuracy: 0.8812
# Epoch 13/20
# 1600/1600 [==============================] - 39s 24ms/step - loss: 0.0245 - accuracy: 0.9931 - val_loss: 0.6136 - val_accuracy: 0.8782
# Epoch 14/20
# 1600/1600 [==============================] - 38s 23ms/step - loss: 0.0180 - accuracy: 0.9952 - val_loss: 0.6173 - val_accuracy: 0.8730
# Epoch 15/20
# 1600/1600 [==============================] - 38s 24ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.7044 - val_accuracy: 0.8768
# Epoch 16/20
# 1600/1600 [==============================] - 36s 23ms/step - loss: 0.0112 - accuracy: 0.9974 - val_loss: 0.7201 - val_accuracy: 0.8732
# Epoch 17/20
# 1600/1600 [==============================] - 38s 24ms/step - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.7116 - val_accuracy: 0.8753
# Epoch 18/20
# 1600/1600 [==============================] - 39s 24ms/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.7381 - val_accuracy: 0.8701
# Epoch 19/20
# 1600/1600 [==============================] - 36s 23ms/step - loss: 0.0078 - accuracy: 0.9981 - val_loss: 0.7683 - val_accuracy: 0.8726
# Epoch 20/20
# 1600/1600 [==============================] - 38s 23ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.8324 - val_accuracy: 0.8727
# Bidirectional LSTM Model Train Accuracy: 0.9987
# Bidirectional LSTM Model Test Accuracy 0.8727

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
